# %% [markdown]
# # DE Scrap

# %%
import os
import PyPDF2
import pandas as pd
import re
import unicodedata

# %%
#### FUNCOES PARA FACILITAR MINHA VIDA

def extrair_texto_pdf(caminho_arquivo, paginas):
  # Abre o arquivo PDF
  with open(caminho_arquivo, 'rb') as f:
    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)
    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []
    # Percorre as páginas do arquivo
    for p in paginas:
      # Lê a página atual
      pagina = pdf_reader.getPage(p)
      # Extrai o texto da página e adiciona à lista
      texto_paginas.append(pagina.extractText())
    # Retorna a lista com o texto das páginas
    return texto_paginas

def clean_text(text):
  # Replace " -\n" and " - \n" with an empty string
  text = re.sub(r" -\n", "", text)
  text = re.sub(r" - \n", "", text)
  
  # Replace ".\n" and ".\s+\n" with " PARAGRAFO "
  text = re.sub(r"\.\s+\n" , " PARAGRAFO ", text)
  text = re.sub(r"\.\n", " PARAGRAFO ", text)
  
  # Replace all newline characters with a space
  text = re.sub(r"\n", " ", text)
  
  return text

# %%
# Get the list of all files in directory
directory = "C:/Users/JVoigt/OneDrive - Universität für Weiterbildung Krems/Dokumente/Python Scripts/champI4.0ns/gesetze_pdf/Länderdokumente/DE"
files = os.listdir(directory)

# get all the files with path:
files_path = []

for i in files:
    o = directory + '/' + i
    files_path.append(o)

# %%
# Gesetz Klimaziele
documento = "gesetz_klimaziele"
country = 'de'
num_doc = 0


#definindo o range de páginas
l = []
for i in range(3, 76):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    i =  re.sub(r"\d+\s+Deutsche Anpassungsstrategie an den Klimawandel\s+", "", i)    # tirando marcacao de pagina
    i =  re.sub(r"\d+\s+Ziele und Rahmen der Deutschen Anpassungsstrategie", "", i)
    i =  re.sub(r"\d+\s+Das Klima verändert sich!", "", i)
    i =  re.sub(r"\d+\s+Was sind die Folgen\? \– Was kann getan werden\?", "", i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])


### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Koalitionsvertrag_Regierungsprogramm

documento = "koalitionsvertrag_regierungsprogramm"
country = 'de'
num_doc = 1


#definindo o range de páginas
l = []
for i in range(4, 178):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])


### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")

# %%
# Leitlinien Kreislaufwirtschaft

documento = "leitlinien_kreislaufwirtschaft"
country = 'de'
num_doc = 2


#definindo o range de páginas
l = []
for i in range(5, 34):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])


### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")

# %%
# Nationale Datenstrategie

documento = "nationale_datenstrategie"
country = 'de'
num_doc = 7

# Parte 1 : texto - tive que fazer um pdf separado porque aquele estava importando errado:

#definindo o range de páginas
l = []
for i in range(0, 58):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

##################################################################################
# # Parte 2 : tabela 1

num_doc = 3

#definindo o range de páginas
l = []
for i in range(64, 105):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = re.sub(r" -\n", "", i)      #quebras
    i = re.sub(r" - \n", "", i)
    i = re.sub(r"\n", " ", i)

    # paragrafo
    i = re.sub(r"\d+\.\d+" , " PARAGRAFO ", i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

#################################################################
# # Parte 3 tabela 2
num_doc = 3

#definindo o range de páginas
l = []
for i in range(105, 119):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# Nationale KI Strategie Addendum

documento = "nationale_ki_strategie_addendum"
country = 'de'
num_doc = 4

#definindo o range de páginas
l = []
for i in range(2, 35 ):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    i = re.sub(r"www\.ki -strategie -deutschland\.de", "", i)
    i = re.sub(r'•', " PARAGRAFO ", i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")

# %%
# Nationale KI Strategie

documento = "nationale_ki_strategie"
country = 'de'
num_doc = 5

#definindo o range de páginas
l = []
for i in range(3, 47):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    i = re.sub(r"www\.ki-strategie-deutschland\.de", "", i)
    content += i                                                    # concatena 

################################################################################ VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")

# %%
files_path[6]
# Out:
# 'C:/Users/JVoigt/OneDrive - Universität für Weiterbildung Krems/Dokumente/Python Scripts/champI4.0ns/gesetze_pdf/Länderdokumente/DE/Roadmap 2025 Holzwirtschaft.pdf'

# %%
# Roadmap 2025 Holzwirtschaft

documento = "roadmap_2025_holzwirtschaft"
country = 'de'
num_doc = 6

#definindo o range de páginas
l = []
for i in range(3, 47):
    l.append(i)

##################################### 

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = clean_text(i)
    i = re.sub(r"www\.ki-strategie-deutschland\.de", "", i)
    i = re.sub(r"[\uf0a1\t]", "", i)
    i = re.sub(r'•', " PARAGRAFO ", i)
    content += i                                                    # concatena 

############################################################################### VERIFICAR CONTENT

corpus = content.split(" PARAGRAFO ")

df = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df = pd.concat([df, df_temp])

### Atribuindo ao df_correto:
df_name = f"df{num_doc}"
exec(f"{df_name} = df")

# %%
dfs = pd.concat([df0, df1, df2, df3 , df4, df5, df6])

dfs.dropna(subset=["corpus"], inplace=True)
dfs = dfs.query('corpus != ""')
dfs = dfs.reset_index()

dfs.to_json("de_concatenado.json")

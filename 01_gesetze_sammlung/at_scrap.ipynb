# %% [markdown]
# # At Scrap

# %%
import os
import PyPDF2
import pandas as pd
import re
import unicodedata

# %%
def extrair_texto_pdf(caminho_arquivo, paginas):
  # Abre o arquivo PDF
  with open(caminho_arquivo, 'rb') as f:
    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)
    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []
    # Percorre as páginas do arquivo
    for p in paginas:
      # Lê a página atual
      pagina = pdf_reader.getPage(p)
      # Extrai o texto da página e adiciona à lista
      texto_paginas.append(pagina.extractText())
    # Retorna a lista com o texto das páginas
    return texto_paginas

# %%
# Get the list of all files in directory
directory = "C:/Users/JVoigt/OneDrive - Universität für Weiterbildung Krems/Dokumente/Python Scripts/champI4.0ns/gesetze_pdf/Länderdokumente/AT"
files = os.listdir(directory)

# get all the files with path:
files_path = []

for i in files:
    o = directory + '/' + i
    files_path.append(o)

# %%
# Digitaler Aktionsplan Chance Daten.pdf

# Abre o arquivo PDF
with open(files_path[0], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in range(3, 21):
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = i.replace(r"Digitaler Aktionsplan Austria", "")   # tirando a numeracao de página
    i = i.replace(r"Digitaler Aktionspl an Austria", "")  # tirando a numeracao de página
    i = i.replace(" -\n", "")                             # juntando palavras que foram separadas na quebra de linha
    i = i.replace("  \n", "  PARAGRAFO  ")                # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                              # tirando as quebras de linha
    i = i.replace("\s{2,}", "\s")                         # tirando dois ou mais whitespaces por um
    i = i.replace("\t", "\s")                             # tirando tabulacao
    content += i                                          # concatena

corpus = content.split("  PARAGRAFO  ")

df_0 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "digitale_aktionsplan_at"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_0 = pd.concat([df_0, df_temp])

# %%
# Nationale Holzwirtschaft.pdf

#páginas:
l = [4]
for i in range(6, 58):
    l.append(i)


# Abre o arquivo PDF
with open(files_path[1], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in range(3,24):
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = re.sub("\.\\n" , " PARAGRAFO ", i)                    # identifiquei o padrao de parágrafo
    i = re.sub("\. \\n" , " PARAGRAFO ", i)                   # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # tirando as quebras de linha
    i = re.sub("Österreichische Holzinitiative \d+", "", i)  #tirando numeracao de página
    i = i.replace("\t", "\s")                                # tirando tabulacao
    content += i                                              # concatena

corpus = content.split(" PARAGRAFO ")

df_1 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "oestereiche_holzinitiative"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_1 = pd.concat([df_1, df_temp])
# Out:
#                     documento country  \
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# 0  oestereiche_holzinitiative      at
# ...

# %%
# Nationale KI Strategie 2023 Addendum
num_doc = 2


#páginas:
l = []
for i in range(5, 25):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = re.sub("\.\\n" , " PARAGRAFO ", i)                    # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\s{1,}\n", " PARAGRAFO ", i)                   # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # tirando as quebras de linha
    i = re.sub('AIM AT 2030 – Annex', "", i)              #tirando numeracao de página
    i = i.replace("\t", "\s")                                # tirando tabulacao
    content += i                                              # concatena

corpus = content.split(" PARAGRAFO ")

df_2 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "nationale_ki_strategie_2023_addendum_at"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_2 = pd.concat([df_2, df_temp])

# %%
# Nationale KI Strategie 2023.pdf'

num_doc = 3


#páginas:
l = [4,6,9,10,11]
for i in range(15, 63):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())
        
content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = re.sub("\.\\n" , " PARAGRAFO ", i)                    # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\s{1,}\n", " PARAGRAFO ", i)                   # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # tirando as quebras de linha
    i = re.sub('AIM AT 2030 – Annex', "", i)              #tirando numeracao de página
    i = i.replace("\t", "\s")                                # tirando tabulacao
    content += i                                              # concatena

corpus = content.split(" PARAGRAFO ")

df_3 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "nationale_ki_strategie_2023"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_3 = pd.concat([df_3, df_temp])

#df_3 = df_3.reset_index()

# %%
# PArte 2 : tabela:

num_doc = 3


#páginas:
l = []
for i in range(63, 70):
    l.append(i)

with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                         # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                                        # juntando palavras que foram separadas na quebra de linha
    i = i.replace("Kapitel Maßnahme Ziel 1 Ziel 2 Ziel 3\n", " ")     #tirando ruido
    i = i.replace("Tabelle 1 Übersicht der Maßnahmen\n", "")          #tirando ruido
    i = re.sub("X\n" , " PARAGRAFO ", i)                              # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                             # paragrafo
    i = re.sub(r"\.X", " ", i)                                        # tirando ruido
    i = i.replace("\n", " ")                                          # tirando as quebras de linha
    i = re.sub('AIM AT 2030 – Annex', "", i)                          #tirando numeracao de página
    i = i.replace("\t", "\s")                                         # tirando tabulacao
    content += i                                                      # concatena

corpus = content.split(" PARAGRAFO ")

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_3 = pd.concat([df_3, df_temp])

df_3 = df_3.reset_index()

# %%
# Nationale Strategie Klimaziele Addendum'

num_doc = 4


#páginas sem tabelas:
l = []
for i in range(4, 120):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())
        
content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                                 # juntando palavras que foram separadas na quebra de linha
    i = re.sub("\.\s+\n" , " PARAGRAFO ", i)                    # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # tirando as quebras de linha
    i =  re.sub(r"EXECUTIVE SUMMARY\s+\n---\s+\d+\s+---", "", i)    # tirando marcacao de pagina
    i =  re.sub(r"---\s+\d+\s+---", "", i)    # tirando marcacao de pagina
    i =  re.sub(r"EXECUTIVE SUMMARY", "", i)
    content += i                                              # concatena

corpus = content.split(" PARAGRAFO ")

df_4 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "nationale_ki_strategie_2023"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_4 = pd.concat([df_4, df_temp])

### Parte 2 Tabela:

num_doc = 4


#páginas com tabelas:
l = []
for i in range(120, 140):
    l.append(i)

texto_paginas = extrair_texto_pdf(files_path[num_doc], l)

content = ""

for i in texto_paginas:
    i = re.sub(r"\n([A-Z][a-z]*)" , " PARAGRAFO ", i)              # identifiquei o padrao de parágrafo
    i = i.replace(" -\n", "")                                    # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                                   # juntando palavras que foram separadas na quebra de linha
    i = i.replace("\n", " ")                                     # tirando as quebras de linha
    content += i                                                 # concatena

corpus = content.split(" PARAGRAFO ")

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_4 = pd.concat([df_4, df_temp])

# %%
# Nationale Strategie Klimaziele'

num_doc = 5


#páginas sem tabelas:
l = []
for i in range(11, 370):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = re.sub("\.\s+\n" , " PARAGRAFO ", i)                 # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # tirando as quebras de linha
    i =  re.sub(r".*\n--\s+\d+\s+--", "", i)                 # tirando marcacao de pagina
    content += i                                              # concatena


corpus = content.split(" PARAGRAFO ")

df_5 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "nationale_strategie_klimaziele"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_5 = pd.concat([df_5, df_temp])


## Parte da tabela

#páginas sem tabelas:
l = []
for i in range(410, 440):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = re.sub(r'\+', '', i)                                 # tirando os + da tabela
    i = re.sub(r'\n', ' ', i)                                # tirando as quebras de linha
    i = re.sub(r'.*---\s+\d+\s+---', '', i)                  # tirando marcacao de pagina
    i = re.sub(r'\/-', '', i)                                # idem
    i = re.sub(r'\s+', ' ', i)                               # tirando excesso de espacos
    i = re.sub(r"Nr.\s+.+?\s+\d+", "", i)                    # tirando o cabecalho da tabela
    i = re.sub(r'\d+\.', ' PARAGRAFO ', i )                  # padrao de paragrafo
    i = re.sub(r"PARAGRAFO  PARAGRAFO  PARAGRAFO", " PARAGRAFO ", i)   # corrigindo o erro
    i = re.sub(r"ANHANG\s+--\s+\d+\s+--", "", i)

    content += i                                              # concatena


corpus = content.split(" PARAGRAFO ")


for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_5 = pd.concat([df_5, df_temp])

df_5 = df_5.reset_index()

# %%
# Nationale Strategie Kreislaufwirtschaft

num_doc = 6


#páginas sem tabelas:
l = []
for i in range(5, 71):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = unicodedata.normalize('NFKD', i)   # removind \xa0
    i = i.replace(" -\n", "")                                # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                               # juntando palavras que foram separadas na quebra de linha
    i = re.sub(r"\.\s+\n" , " PARAGRAFO ", i)                # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                                  # paragrafo
    i = i.replace("\n", " ")                                 # quebra de linha
    i =  re.sub(r"Die österreichische Kreislaufwirtschaftsstrategie \d+", "", i)    # tirando marcacao de pagina
    content += i                                              # concatena 

corpus = content.split(" PARAGRAFO ")

df_6 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "nationale_strategie_kreislaufwirtschaft"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_6 = pd.concat([df_6, df_temp])

# %%
# Nationale Strategie Regierungsprogramm   # esse documento tem aquela divisao de página em duas colunas, mas eu fiz um teste a importacao deu certo

num_doc = 7


#páginas sem tabelas:
l = []
for i in range(5, 228):
    l.append(i)

# Abre o arquivo PDF
with open(files_path[num_doc], 'rb') as f:

    # Cria um objeto PDFReader a partir do arquivo
    pdf_reader = PyPDF2.PdfFileReader(f)

    # Inicializa uma lista para armazenar o texto de cada página
    texto_paginas = []

    # Percorre as páginas do arquivo
    
    for p in l:
        # Lê a página atual
        pagina = pdf_reader.getPage(p)
        # Extrai o texto da página e adiciona à lista
        texto_paginas.append(pagina.extractText())

content = ""

for i in texto_paginas:
    i = i.replace(" -\n", "")                                # juntando palavras que foram separadas na quebra de linha
    i = i.replace(" - \n", "")                               # juntando palavras que foram separadas na quebra de linha
    i = re.sub(r"\.\s+\n" , " PARAGRAFO ", i)                # identifiquei o padrao de parágrafo
    i = re.sub(r"\.\n", " PARAGRAFO ", i)                    # paragrafo
    i = i.replace("\n", " ")                                 # quebra de linha
    i =  re.sub(r"\d+\s+Regierungsprogramm 2020  – 2024", "", i)    # tirando marcacao de pagina
    content += i                                              # concatena 


corpus = content.split(" PARAGRAFO ")

df_7 = pd.DataFrame(columns = ['documento', 'country', 'corpus'] )

documento = "regierungsprogramm"
country = 'at'

for i in corpus:
    df_temp = pd.DataFrame({'documento': [documento],
                            'country': [country],  
                            'corpus': [i]})
    df_7 = pd.concat([df_7, df_temp])

# %%
dfs = pd.concat([df_0, df_1, df_2, df_3, df_4, df_5, df_6, df_7])

dfs = dfs.drop(columns=["index"])
dfs.dropna(subset=["corpus"], inplace=True)
dfs = dfs.query('corpus != ""')
dfs = dfs.reset_index()

dfs.to_json("at_concatenado.json")
